# %%
import math
from collections import defaultdict
#theory
#(40*intMrk)+(60*extMrk)
mp={"O":91,"A+":81,"A":71,"B+":61,"B":51}
#gr="A+"
while 1:
    im,gr=float(input("Internal mark out of 100: ")),str(input("Required Grade: "))
    res=((mp.get(gr)-(0.4*im))/60)*100
    print(res)
# Out:
# 56.33333333333332
# 61.0
# 56.33333333333332
# 89.66666666666666
# 73.0

# %%
import math
# Lab
mp={"O":91,"A+":81,"A":71,"B+":61,"B":51}
#gr="A+"
im,gr=float(input("Internal mark out of 100: ")),str(input("Required Grade: "))
res=((mp.get(gr)-(0.6*im))/40)*100
print(math.floor(res))
# Out:
# 38

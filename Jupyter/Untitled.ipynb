# %%
def tribonacci(n):
    trib = [0, 0, 1]
    for i in range(3, n):
        trib.append(trib[-1] + trib[-2] + trib[-3])
    return trib[:n]
tribonacci(10)
# Out:
# [0, 0, 1, 1, 2, 4, 7, 13, 24, 44]

# %%
a=[]
if not a:
    print("The list is empty")
else:
    print("The list is not empty")
# Out:
# The list is empty

# %%
print("even" if int(input("Enter number to check odd or even"))%2==0)
# Out:
#   Cell In[6], line 1
#     print("even" if int(input("Enter number to check odd or even"))%2==0)
#           ^
# SyntaxError: expected 'else' after 'if' expression

# %%
print("Even" if int(input("Enter a number: ")) % 2 == 0 else "Odd")

# %%
import matplotlib as plt 

# Sorting a dictionary by its values
def sort_dict_by_value(d):
    # Sort the dictionary by value in ascending order
    sorted_dict = dict(sorted(d.items(), key=lambda item: item[1]))
    return sorted_dict
ax = plt.subplots(figsize=(3.5, 3))
ax.plot(x, y, 'rs-', label='label')
_ = ax.legend(frameon=False, loc=0, title='')

# Set axis labels, display in bold
ax.set_xlabel("X (unit)", fontweight="bold")
ax.set_ylabel("Y (unit)", fontweight="bold")

plt.show()


# Example dictionary
example_dict = {'a': 3, 'b': 1, 'c': 2}
sorted_dict = sort_dict_by_value(example_dict)
print("Sorted Dictionary:", sorted_dict)
# Out:
#   Cell In[1], line 5
#     return sorted_dictfig, ax = plt.subplots(figsize=(3.5, 3))
#                               ^
# SyntaxError: invalid syntax

# %%
# Flattening a nested list
def flatten_nested_list(nested_list):
    flat_list = []
    for sublist in nested_list:
        if isinstance(subfig, ax = plt.subplots(figsize=(3.5, 3))

_ = ax.plot(x, y, 'rs-', label='label')
_ = ax.legend(frameon=False, loc=0, title='')

# Set axis labels, display in bold
ax.set_xlabel("X (unit)", fontweight="bold")
ax.set_ylabel("Y (unit)", fontweight="bold")

plt.show()
list, list):
            flat_list.extend(flatten_nested_list(sublist))  # Recursively flatten sublists
        else:
            flat_list.append(sublist)
    return flat_list

# Example nested list
nested_list = [1, [2, [3, 4], 5], [6, 7], 8]
flattened_list = flatten_nested_list(nested_list)
print("Flattened List:", flattened_list)
# Out:
# Flattened List: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Display powers of 2 using a lambda function
powers_of_2 = list(map(lambda x: 2 ** x, range(10)))
print("Powers of 2:", powers_of_2)

# Display powers of 3 using a lambda function
powers_of_3 = list(map(lambda x: 3 ** x, range(10)))
print("Powers of 3:", powers_of_3)
# Out:
# Powers of 2: [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]
# Powers of 3: [1, 3, 9, 27, 81, 243, 729, 2187, 6561, 19683]
